# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("chennai_house_price_prediction.csv")

# %%
data.head()
# Out:
#    PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0  P03210  Karapakkam      1004            131        1.0         1.0       3
# 1  P09411  Anna Nagar      1986             26        2.0         1.0       5
# 2  P01812       Adyar       909             70        1.0         1.0       3
# 3  P05346   Velachery      1855             14        3.0         2.0       5
# 4  P06210  Karapakkam      1226             84        1.0         1.0       3
#
#   SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL  STREET MZZONE  QS_ROOMS  \
# 0  AbNormal        Yes  Commercial        AllPub   Paved      A       4.0
# 1  AbNormal         No  Commercial        AllPub  Gravel     RH       4.9
# 2  AbNormal        Yes  Commercial           ELO  Gravel     RL       4.1
# 3    Family         No      Others       NoSewr    Paved      I       4.7
# 4  AbNormal        Yes      Others        AllPub  Gravel      C       3.0
#
#    QS_BATHROOM  QS_BEDROOM  QS_OVERALL  COMMIS  SALES_PRICE
# 0          3.9         4.9       4.330  144400      7600000
# 1          4.2         2.5       3.765  304049     21717770
# 2          3.8         2.2       3.090   92114     13159200
# 3          3.9         3.6       4.010   77042      9630290
# 4          2.5         4.1       3.290   74063      7406250

# %% [markdown]
# ### Drop Duplicates (if any)

# %%
data.drop_duplicates()
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0     P03210  Karapakkam      1004            131        1.0         1.0
# 1     P09411  Anna Nagar      1986             26        2.0         1.0
# 2     P01812       Adyar       909             70        1.0         1.0
# 3     P05346   Velachery      1855             14        3.0         2.0
# 4     P06210  Karapakkam      1226             84        1.0         1.0
# 5     P00219    Chrompet      1220             36        2.0         1.0
# 6     P09105    Chrompet      1167            137        1.0         1.0
# 7     P09679   Velachery      1847            176        3.0         2.0
# 8     P03377    Chrompet       771            175        1.0         1.0
# 9     P09623   Velachery      1635             74        2.0         1.0
# 10    P09540    Chrompet      1203             78        2.0         1.0
# 11    P07121    Chrompet      1054            143        1.0         1.0
# 12    P05512    Chrompet      1196            137        1.0         1.0
# 13    P09370       Adyar      1056             83        1.0         1.0
# 14    P04085   Velachery      1865            157        3.0         2.0
# 15    P06328   Velachery      1868            148        3.0         2.0
# 16    P06039  Karapakkam      1639            175        2.0         2.0
# 17    P02016    Chrompet       796            134        1.0         1.0
# 18    P08160       Adyar      1136             69        1.0         1.0
# 19    P01372  Anna Nagar      1902            168        2.0         1.0
# 20    P00936    Chrompet      1069             53        1.0         1.0
# 21    P07346    Chrompet       931             96        1.0         1.0
# 22    P06851    KK Nagar      2010            114        3.0         2.0
# 23    P04665    Chrompet      1074            100        1.0         1.0
# 24    P00902      TNagar      1972            111        2.0         1.0
# 25    P00293     T Nagar      1685            105        1.0         1.0
# 26    P02235       Adyar      1130             29        1.0         1.0
# 27    P04080  Karapakkam      1301             59        1.0         1.0
# 28    P02677       Adyar       730            185        1.0         1.0
# 29    P00755     T Nagar      1806            138        2.0         1.0
# ...      ...         ...       ...            ...        ...         ...
# 7079  P01918       Adyar       934             91        1.0         1.0
# 7080  P08039       Adyar       903            108        1.0         1.0
# 7081  P00603     T Nagar      1946            148        2.0         1.0
# 7082  P08060       Adyar       791             71        1.0         1.0
# 7083  P09758   Velachery      1992            147        3.0         2.0
# 7084  P07245    Chrompet       858             32        1.0         1.0
# 7085  P08537    Chrompet       990            181        1.0         1.0
# 7086  P03059  Karapakkam       705            100        1.0         1.0
# 7087  P05763  Karapakkam      1008            194        1.0         1.0
# 7088  P05164  Karapakkam      1696             48        2.0         2.0
# 7089  P06915   Velachery      1907             86        3.0         2.0
# 7090  P02629    KK Nagar      1960             98        3.0         2.0
# 7091  P03495    KK Nagar      2051             30        3.0         2.0
# 7092  P00465    Chrompet      1202            134        2.0         1.0
# 7093  P07282   Velachery      1941             90        3.0         2.0
# 7094  P07645    KK Nagar      2456            171        4.0         2.0
# 7095  P08967  Anna Nagar      1955             33        2.0         1.0
# 7096  P03146    Chrompet      1275              3        2.0         1.0
# 7097  P05670  Anna Nagar      1860            174        2.0         1.0
# 7098  P00629  Anna Nagar      1611            144        1.0         1.0
# 7099  P03828       Adyar       895            197        1.0         1.0
# 7100  P05438     T Nagar      1733            191        1.0         1.0
# 7101  P05042  Karapakkam       666             51        1.0         1.0
# 7102  P05560  Karapakkam       701            100        1.0         1.0
# 7103  P05133  Karapakkam      1462             68        2.0         2.0
# 7104  P03834  Karapakkam       598             51        1.0         1.0
# 7105  P10000   Velachery      1897             52        3.0         2.0
# 7106  P09594   Velachery      1614            152        2.0         1.0
# 7107  P06508  Karapakkam       787             40        1.0         1.0
# 7108  P09794   Velachery      1896            156        3.0         2.0
#
#       N_ROOM    SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL     STREET  \
# 0          3     AbNormal        Yes  Commercial        AllPub      Paved
# 1          5     AbNormal         No  Commercial        AllPub     Gravel
# 2          3     AbNormal        Yes  Commercial           ELO     Gravel
# 3          5       Family         No      Others       NoSewr       Paved
# 4          3     AbNormal        Yes      Others        AllPub     Gravel
# 5          4      Partial         No  Commercial        NoSeWa  No Access
# 6          3      Partial         No       Other        AllPub  No Access
# 7          5       Family         No  Commercial        AllPub     Gravel
# 8          2      AdjLand         No      Others       NoSewr       Paved
# 9          4     AbNormal         No      Others           ELO  No Access
# 10         4      AdjLand        Yes  Commercial        AllPub  No Access
# 11         3      Partial         No      Others       NoSewr      Gravel
# 12         3       Family         No      Others       NoSewr   No Access
# 13         3      Partial        Yes      Others       NoSewr       Paved
# 14         5       Family         No  Commercial       NoSewr       Paved
# 15         5       Family         No  Commercial       NoSewr      Gravel
# 16         4  Normal Sale        Yes       House           ELO     Gravel
# 17         2      AdjLand        Yes  Commercial        AllPub  No Access
# 18         3  Normal Sale        Yes      Others        AllPub      Paved
# 19         5       Family        Yes  Commercial           ELO      Paved
# 20         3     AbNormal        Yes      Others       NoSewr       Paved
# 21         3     AbNormal        Yes      Others           ELO      Paved
# 22         5      Partial         No      Others       NoSewr      Gravel
# 23         3     AbNormal         No      Others       NoSewr      Gravel
# 24         5      AdjLand         No      Others       NoSewr   No Access
# 25         4       Family         No       House       NoSewr      Gravel
# 26         3       Family        Yes  Commercial           ELO      Paved
# 27         3  Normal Sale        Yes      Others       NoSewr      Gravel
# 28         2      AdjLand        Yes       House           ELO     Gravel
# 29         5       Family         No       House        NoSeWa      Paved
# ...      ...          ...        ...         ...           ...        ...
# 7079       3     AbNormal         No      Others        NoSeWa      Paved
# 7080       3     AbNormal        Yes       House       NoSewr       Paved
# 7081       5      AdjLand         No      Others        NoSeWa     Gravel
# 7082       2      Partial        Yes  Commercial        NoSeWa     Gravel
# 7083       5      Partial         No       House        NoSeWa     Gravel
# 7084       3      Partial        Yes       House        NoSeWa  No Access
# 7085       3     AbNormal         No  Commercial           ELO      Paved
# 7086       2       Family        Yes       House           ELO     Gravel
# 7087       3      Partial        Yes  Commercial        NoSeWa  No Access
# 7088       4  Normal Sale         No       House       NoSewr   No Access
# 7089       5  Normal Sale         No  Commercial           ELO      Paved
# 7090       5  Normal Sale         No      Others       NoSewr       Paved
# 7091       5      Partial         No       House       NoSewr      Gravel
# 7092       4       Family         No      Others       NoSewr       Paved
# 7093       5     AbNormal        Yes       House           ELO  No Access
# 7094       6      AdjLand        Yes       House       NoSewr      Gravel
# 7095       5       Family         No       House       NoSewr       Paved
# 7096       4     AbNormal         No       House           ELO     Gravel
# 7097       5     AbNormal         No      Others        AllPub     Gravel
# 7098       4      Partial        Yes      Others        NoSeWa      Paved
# 7099       3      AdjLand        Yes       House       NoSewr   No Access
# 7100       4     AbNormal        Yes  Commercial        NoSeWa  No Access
# 7101       2      AdjLand        Yes      Others           ELO     Gravel
# 7102       2     AbNormal         No       House        NoSeWa     Gravel
# 7103       4       Family         No      Others        NoSeWa     Gravel
# 7104       2      AdjLand         No      Others           ELO  No Access
# 7105       5       Family        Yes      Others        NoSeWa  No Access
# 7106       4  Normal Sale         No       House        NoSeWa     Gravel
# 7107       2      Partial        Yes  Commercial           ELO      Paved
# 7108       5      Partial        Yes      Others           ELO      Paved
#
#      MZZONE  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  COMMIS  \
# 0         A       4.0          3.9         4.9       4.330  144400
# 1        RH       4.9          4.2         2.5       3.765  304049
# 2        RL       4.1          3.8         2.2       3.090   92114
# 3         I       4.7          3.9         3.6       4.010   77042
# 4         C       3.0          2.5         4.1       3.290   74063
# 5        RH       4.5          2.6         3.1       3.320  198316
# 6        RL       3.6          2.1         2.5       2.670   33955
# 7        RM       2.4          4.5         2.1       3.260  235204
# 8        RM       2.9          3.7         4.0       3.550   33236
# 9         I       3.1          3.1         3.3       3.160  121255
# 10       RM       4.0          3.2         4.5       3.830  119504
# 11       RM       2.2          3.1         3.3       2.890  141746
# 12       RL       2.1          2.5         2.1       2.260   35097
# 13       RH       2.2          3.4         3.7       3.190   37546
# 14       RM       4.8          2.2         4.9       3.660  294494
# 15       RH       3.8          3.8         3.1         NaN  188569
# 16        I       2.3          3.2         4.8       3.570   77904
# 17       RL       3.5          4.6         4.7       4.300  130951
# 18        A       4.6          2.6         2.9       3.350   49725
# 19       RL       4.5          4.9         4.9       4.760  212032
# 20       RM       2.8          2.7         4.9       3.390   43622
# 21       RL       4.2          3.1         3.1       3.430   27558
# 22       RH       3.4          4.5         3.4       3.730  262210
# 23       RL       3.0          3.4         4.9       3.730   86646
# 24       RH       4.1          4.4         2.8       3.590  167073
# 25       RM       2.8          4.4         4.0       3.740  176415
# 26       RH       2.3          2.5         2.2       2.290   53533
# 27        C       2.8          2.7         3.8       3.170   71457
# 28       RL       2.7          4.6         4.9       4.180   53090
# 29       RH       4.1          5.0         3.0       3.830  113382
# ...     ...       ...          ...         ...         ...     ...
# 7079     RH       2.6          4.8         2.0       2.740  104227
# 7080      C       4.8          4.4         4.0       4.320   68502
# 7081     RH       2.7          3.8         2.9       3.065  171371
# 7082      C       4.9          3.8         4.2       4.330  146742
# 7083     RM       2.4          2.8         2.4       2.580  111291
# 7084     RL       2.9          3.0         3.9       3.240   30174
# 7085     RL       3.0          4.2         4.8       4.020  203252
# 7086      A       4.7          3.1         4.8       4.260   59641
# 7087     RL       2.5          4.5         3.4       3.460  200646
# 7088     RH       4.9          4.9         5.0       4.940   57312
# 7089      C       2.4          4.0         4.3       3.690  210380
# 7090     RL       5.0          3.7         3.3       3.930  122051
# 7091     RM       3.0          2.1         4.4       3.290  160131
# 7092     RH       3.1          3.4         3.5       3.340   25831
# 7093     RH       3.4          4.6         3.7       4.030  141304
# 7094     RM       5.0          5.0         3.0       4.200  353880
# 7095     RM       3.7          3.4         2.8       3.265  146396
# 7096     RL       3.9          3.8         4.1       3.920   86339
# 7097     RH       4.6          3.4         3.2       3.740   70557
# 7098     RM       3.2          3.7         2.9       3.205  209172
# 7099      I       3.6          4.7         4.2       4.120    7372
# 7100     RL       3.4          3.7         2.1       2.890  312026
# 7101      I       3.2          4.4         2.5       3.280   74541
# 7102     RH       4.2          3.0         2.0       2.960  141088
# 7103     RM       2.7          3.3         3.6       3.240  178358
# 7104     RM       3.0          2.2         2.4       2.520  107060
# 7105     RH       3.6          4.5         3.3       3.920  205551
# 7106      I       4.3          4.2         2.9       3.840  167028
# 7107     RL       4.6          3.8         4.1       4.160  119098
# 7108      I       3.1          3.5         4.3       3.640   79812
#
#       SALES_PRICE
# 0         7600000
# 1        21717770
# 2        13159200
# 3         9630290
# 4         7406250
# 5        12394750
# 6         8488790
# 7        16800250
# 8         8308970
# 9         8083650
# 10       14938000
# 11        9449730
# 12        8774370
# 13        9386490
# 14       15499680
# 15       15714080
# 16        8656000
# 17       10912550
# 18        8287550
# 19       21203240
# 20       10905530
# 21        9185970
# 22       10925400
# 23        9627380
# 24       13922760
# 25       12601080
# 26       13383350
# 27        7939625
# 28        8848285
# 29       11338200
# ...           ...
# 7079      8017445
# 7080      7611350
# 7081     14280890
# 7082      9782785
# 7083     11129100
# 7084      7543400
# 7085     11956000
# 7086      4587750
# 7087      9120250
# 7088      7164000
# 7089     14025340
# 7090     11095520
# 7091     11437920
# 7092      8610340
# 7093      9420260
# 7094     14155200
# 7095     13308750
# 7096      9593250
# 7097     14111320
# 7098     13944780
# 7099      7371800
# 7100     19501600
# 7101      6211750
# 7102      5643500
# 7103      9387250
# 7104      5353000
# 7105     10818480
# 7106      8351410
# 7107      8507000
# 7108      9976480
#
# [7109 rows x 19 columns]

# %%
data.drop_duplicates(subset="AREA")
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0     P03210  Karapakkam      1004            131        1.0         1.0
# 1     P09411  Anna Nagar      1986             26        2.0         1.0
# 2     P01812       Adyar       909             70        1.0         1.0
# 3     P05346   Velachery      1855             14        3.0         2.0
# 5     P00219    Chrompet      1220             36        2.0         1.0
# 22    P06851    KK Nagar      2010            114        3.0         2.0
# 24    P00902      TNagar      1972            111        2.0         1.0
# 25    P00293     T Nagar      1685            105        1.0         1.0
# 175   P00920     Chrompt       869             39        1.0         1.0
# 245   P00166     Chrmpet      1277            111        2.0         1.0
# 587   P06395   Karapakam       520            130        1.0         1.0
# 855   P00659   Ana Nagar      1894            189        2.0         1.0
# 1132  P01455    Chormpet       991            105        1.0         1.0
# 1442  P09422        Adyr       784             17        1.0         1.0
# 3817  P09948    Velchery      1696            189        2.0         1.0
# 4417  P00137   Ann Nagar      1704            133        1.0         1.0
# 7074  P06491     KKNagar      1521             14        2.0         1.0
#
#       N_ROOM SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL     STREET MZZONE  \
# 0          3  AbNormal        Yes  Commercial        AllPub      Paved      A
# 1          5  AbNormal         No  Commercial        AllPub     Gravel     RH
# 2          3  AbNormal        Yes  Commercial           ELO     Gravel     RL
# 3          5    Family         No      Others       NoSewr       Paved      I
# 5          4   Partial         No  Commercial        NoSeWa  No Access     RH
# 22         5   Partial         No      Others       NoSewr      Gravel     RH
# 24         5   AdjLand         No      Others       NoSewr   No Access     RH
# 25         4    Family         No       House       NoSewr      Gravel     RM
# 175        3    Family         No      Others       NoSewr   No Access     RM
# 245        4   AdjLand        Yes  Commercial        AllPub  No Access     RM
# 587        2   Partial         No       House           ELO      Paved     RL
# 855        5   AdjLand        Yes      Others           ELO  No Access     RL
# 1132       3   AdjLand         No       House        NoSeWa      Paved     RM
# 1442       2   AdjLand         No       House       NoSewr      Gravel     RM
# 3817       4   Partial         No  Commercial           ELO     Gravel      I
# 4417       4   Partial        Yes       House       NoSewr   No Access     RH
# 7074       4  Adj Land         No  Commercial        NoSeWa     Gravel     RH
#
#       QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  COMMIS  SALES_PRICE
# 0          4.0          3.9         4.9       4.330  144400      7600000
# 1          4.9          4.2         2.5       3.765  304049     21717770
# 2          4.1          3.8         2.2       3.090   92114     13159200
# 3          4.7          3.9         3.6       4.010   77042      9630290
# 5          4.5          2.6         3.1       3.320  198316     12394750
# 22         3.4          4.5         3.4       3.730  262210     10925400
# 24         4.1          4.4         2.8       3.590  167073     13922760
# 25         2.8          4.4         4.0       3.740  176415     12601080
# 175        4.3          4.8         3.3       4.200  138935      8172630
# 245        4.0          3.8         3.4       3.740   47131     15710400
# 587        3.7          4.2         3.9       3.930   82433      4849000
# 855        5.0          5.0         3.9       4.560  243277     14310420
# 1132       2.2          4.8         4.6       3.960   52590      8765000
# 1442       4.8          2.0         2.6       3.140   90440      9044045
# 3817       3.4          2.7         3.1       3.000  163136     13594630
# 4417       2.0          2.7         2.2       2.255  102367     11374070
# 7074       3.8          2.4         3.1       3.100  327926     13117020

# %%
data.drop_duplicates(subset="AREA").shape
# Out:
# (17, 19)

# %%
data.shape
# Out:
# (7109, 19)

# %% [markdown]
# ### Handling missing values

# %%
#Drop rows having missing values

# %%
data.dropna(axis=0,how="any")
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 0     P03210  Karapakkam      1004            131        1.0         1.0
# 1     P09411  Anna Nagar      1986             26        2.0         1.0
# 2     P01812       Adyar       909             70        1.0         1.0
# 3     P05346   Velachery      1855             14        3.0         2.0
# 4     P06210  Karapakkam      1226             84        1.0         1.0
# 5     P00219    Chrompet      1220             36        2.0         1.0
# 6     P09105    Chrompet      1167            137        1.0         1.0
# 7     P09679   Velachery      1847            176        3.0         2.0
# 8     P03377    Chrompet       771            175        1.0         1.0
# 9     P09623   Velachery      1635             74        2.0         1.0
# 10    P09540    Chrompet      1203             78        2.0         1.0
# 11    P07121    Chrompet      1054            143        1.0         1.0
# 12    P05512    Chrompet      1196            137        1.0         1.0
# 13    P09370       Adyar      1056             83        1.0         1.0
# 14    P04085   Velachery      1865            157        3.0         2.0
# 16    P06039  Karapakkam      1639            175        2.0         2.0
# 17    P02016    Chrompet       796            134        1.0         1.0
# 18    P08160       Adyar      1136             69        1.0         1.0
# 19    P01372  Anna Nagar      1902            168        2.0         1.0
# 20    P00936    Chrompet      1069             53        1.0         1.0
# 21    P07346    Chrompet       931             96        1.0         1.0
# 22    P06851    KK Nagar      2010            114        3.0         2.0
# 23    P04665    Chrompet      1074            100        1.0         1.0
# 24    P00902      TNagar      1972            111        2.0         1.0
# 25    P00293     T Nagar      1685            105        1.0         1.0
# 26    P02235       Adyar      1130             29        1.0         1.0
# 27    P04080  Karapakkam      1301             59        1.0         1.0
# 28    P02677       Adyar       730            185        1.0         1.0
# 29    P00755     T Nagar      1806            138        2.0         1.0
# 30    P06980  Anna Nagar      1981            173        2.0         1.0
# ...      ...         ...       ...            ...        ...         ...
# 7079  P01918       Adyar       934             91        1.0         1.0
# 7080  P08039       Adyar       903            108        1.0         1.0
# 7081  P00603     T Nagar      1946            148        2.0         1.0
# 7082  P08060       Adyar       791             71        1.0         1.0
# 7083  P09758   Velachery      1992            147        3.0         2.0
# 7084  P07245    Chrompet       858             32        1.0         1.0
# 7085  P08537    Chrompet       990            181        1.0         1.0
# 7086  P03059  Karapakkam       705            100        1.0         1.0
# 7087  P05763  Karapakkam      1008            194        1.0         1.0
# 7088  P05164  Karapakkam      1696             48        2.0         2.0
# 7089  P06915   Velachery      1907             86        3.0         2.0
# 7090  P02629    KK Nagar      1960             98        3.0         2.0
# 7091  P03495    KK Nagar      2051             30        3.0         2.0
# 7092  P00465    Chrompet      1202            134        2.0         1.0
# 7093  P07282   Velachery      1941             90        3.0         2.0
# 7094  P07645    KK Nagar      2456            171        4.0         2.0
# 7095  P08967  Anna Nagar      1955             33        2.0         1.0
# 7096  P03146    Chrompet      1275              3        2.0         1.0
# 7097  P05670  Anna Nagar      1860            174        2.0         1.0
# 7098  P00629  Anna Nagar      1611            144        1.0         1.0
# 7099  P03828       Adyar       895            197        1.0         1.0
# 7100  P05438     T Nagar      1733            191        1.0         1.0
# 7101  P05042  Karapakkam       666             51        1.0         1.0
# 7102  P05560  Karapakkam       701            100        1.0         1.0
# 7103  P05133  Karapakkam      1462             68        2.0         2.0
# 7104  P03834  Karapakkam       598             51        1.0         1.0
# 7105  P10000   Velachery      1897             52        3.0         2.0
# 7106  P09594   Velachery      1614            152        2.0         1.0
# 7107  P06508  Karapakkam       787             40        1.0         1.0
# 7108  P09794   Velachery      1896            156        3.0         2.0
#
#       N_ROOM    SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL     STREET  \
# 0          3     AbNormal        Yes  Commercial        AllPub      Paved
# 1          5     AbNormal         No  Commercial        AllPub     Gravel
# 2          3     AbNormal        Yes  Commercial           ELO     Gravel
# 3          5       Family         No      Others       NoSewr       Paved
# 4          3     AbNormal        Yes      Others        AllPub     Gravel
# 5          4      Partial         No  Commercial        NoSeWa  No Access
# 6          3      Partial         No       Other        AllPub  No Access
# 7          5       Family         No  Commercial        AllPub     Gravel
# 8          2      AdjLand         No      Others       NoSewr       Paved
# 9          4     AbNormal         No      Others           ELO  No Access
# 10         4      AdjLand        Yes  Commercial        AllPub  No Access
# 11         3      Partial         No      Others       NoSewr      Gravel
# 12         3       Family         No      Others       NoSewr   No Access
# 13         3      Partial        Yes      Others       NoSewr       Paved
# 14         5       Family         No  Commercial       NoSewr       Paved
# 16         4  Normal Sale        Yes       House           ELO     Gravel
# 17         2      AdjLand        Yes  Commercial        AllPub  No Access
# 18         3  Normal Sale        Yes      Others        AllPub      Paved
# 19         5       Family        Yes  Commercial           ELO      Paved
# 20         3     AbNormal        Yes      Others       NoSewr       Paved
# 21         3     AbNormal        Yes      Others           ELO      Paved
# 22         5      Partial         No      Others       NoSewr      Gravel
# 23         3     AbNormal         No      Others       NoSewr      Gravel
# 24         5      AdjLand         No      Others       NoSewr   No Access
# 25         4       Family         No       House       NoSewr      Gravel
# 26         3       Family        Yes  Commercial           ELO      Paved
# 27         3  Normal Sale        Yes      Others       NoSewr      Gravel
# 28         2      AdjLand        Yes       House           ELO     Gravel
# 29         5       Family         No       House        NoSeWa      Paved
# 30         5      AdjLand         No       House           ELO  No Access
# ...      ...          ...        ...         ...           ...        ...
# 7079       3     AbNormal         No      Others        NoSeWa      Paved
# 7080       3     AbNormal        Yes       House       NoSewr       Paved
# 7081       5      AdjLand         No      Others        NoSeWa     Gravel
# 7082       2      Partial        Yes  Commercial        NoSeWa     Gravel
# 7083       5      Partial         No       House        NoSeWa     Gravel
# 7084       3      Partial        Yes       House        NoSeWa  No Access
# 7085       3     AbNormal         No  Commercial           ELO      Paved
# 7086       2       Family        Yes       House           ELO     Gravel
# 7087       3      Partial        Yes  Commercial        NoSeWa  No Access
# 7088       4  Normal Sale         No       House       NoSewr   No Access
# 7089       5  Normal Sale         No  Commercial           ELO      Paved
# 7090       5  Normal Sale         No      Others       NoSewr       Paved
# 7091       5      Partial         No       House       NoSewr      Gravel
# 7092       4       Family         No      Others       NoSewr       Paved
# 7093       5     AbNormal        Yes       House           ELO  No Access
# 7094       6      AdjLand        Yes       House       NoSewr      Gravel
# 7095       5       Family         No       House       NoSewr       Paved
# 7096       4     AbNormal         No       House           ELO     Gravel
# 7097       5     AbNormal         No      Others        AllPub     Gravel
# 7098       4      Partial        Yes      Others        NoSeWa      Paved
# 7099       3      AdjLand        Yes       House       NoSewr   No Access
# 7100       4     AbNormal        Yes  Commercial        NoSeWa  No Access
# 7101       2      AdjLand        Yes      Others           ELO     Gravel
# 7102       2     AbNormal         No       House        NoSeWa     Gravel
# 7103       4       Family         No      Others        NoSeWa     Gravel
# 7104       2      AdjLand         No      Others           ELO  No Access
# 7105       5       Family        Yes      Others        NoSeWa  No Access
# 7106       4  Normal Sale         No       House        NoSeWa     Gravel
# 7107       2      Partial        Yes  Commercial           ELO      Paved
# 7108       5      Partial        Yes      Others           ELO      Paved
#
#      MZZONE  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  COMMIS  \
# 0         A       4.0          3.9         4.9       4.330  144400
# 1        RH       4.9          4.2         2.5       3.765  304049
# 2        RL       4.1          3.8         2.2       3.090   92114
# 3         I       4.7          3.9         3.6       4.010   77042
# 4         C       3.0          2.5         4.1       3.290   74063
# 5        RH       4.5          2.6         3.1       3.320  198316
# 6        RL       3.6          2.1         2.5       2.670   33955
# 7        RM       2.4          4.5         2.1       3.260  235204
# 8        RM       2.9          3.7         4.0       3.550   33236
# 9         I       3.1          3.1         3.3       3.160  121255
# 10       RM       4.0          3.2         4.5       3.830  119504
# 11       RM       2.2          3.1         3.3       2.890  141746
# 12       RL       2.1          2.5         2.1       2.260   35097
# 13       RH       2.2          3.4         3.7       3.190   37546
# 14       RM       4.8          2.2         4.9       3.660  294494
# 16        I       2.3          3.2         4.8       3.570   77904
# 17       RL       3.5          4.6         4.7       4.300  130951
# 18        A       4.6          2.6         2.9       3.350   49725
# 19       RL       4.5          4.9         4.9       4.760  212032
# 20       RM       2.8          2.7         4.9       3.390   43622
# 21       RL       4.2          3.1         3.1       3.430   27558
# 22       RH       3.4          4.5         3.4       3.730  262210
# 23       RL       3.0          3.4         4.9       3.730   86646
# 24       RH       4.1          4.4         2.8       3.590  167073
# 25       RM       2.8          4.4         4.0       3.740  176415
# 26       RH       2.3          2.5         2.2       2.290   53533
# 27        C       2.8          2.7         3.8       3.170   71457
# 28       RL       2.7          4.6         4.9       4.180   53090
# 29       RH       4.1          5.0         3.0       3.830  113382
# 30       RL       2.0          3.1         3.2       2.755  218831
# ...     ...       ...          ...         ...         ...     ...
# 7079     RH       2.6          4.8         2.0       2.740  104227
# 7080      C       4.8          4.4         4.0       4.320   68502
# 7081     RH       2.7          3.8         2.9       3.065  171371
# 7082      C       4.9          3.8         4.2       4.330  146742
# 7083     RM       2.4          2.8         2.4       2.580  111291
# 7084     RL       2.9          3.0         3.9       3.240   30174
# 7085     RL       3.0          4.2         4.8       4.020  203252
# 7086      A       4.7          3.1         4.8       4.260   59641
# 7087     RL       2.5          4.5         3.4       3.460  200646
# 7088     RH       4.9          4.9         5.0       4.940   57312
# 7089      C       2.4          4.0         4.3       3.690  210380
# 7090     RL       5.0          3.7         3.3       3.930  122051
# 7091     RM       3.0          2.1         4.4       3.290  160131
# 7092     RH       3.1          3.4         3.5       3.340   25831
# 7093     RH       3.4          4.6         3.7       4.030  141304
# 7094     RM       5.0          5.0         3.0       4.200  353880
# 7095     RM       3.7          3.4         2.8       3.265  146396
# 7096     RL       3.9          3.8         4.1       3.920   86339
# 7097     RH       4.6          3.4         3.2       3.740   70557
# 7098     RM       3.2          3.7         2.9       3.205  209172
# 7099      I       3.6          4.7         4.2       4.120    7372
# 7100     RL       3.4          3.7         2.1       2.890  312026
# 7101      I       3.2          4.4         2.5       3.280   74541
# 7102     RH       4.2          3.0         2.0       2.960  141088
# 7103     RM       2.7          3.3         3.6       3.240  178358
# 7104     RM       3.0          2.2         2.4       2.520  107060
# 7105     RH       3.6          4.5         3.3       3.920  205551
# 7106      I       4.3          4.2         2.9       3.840  167028
# 7107     RL       4.6          3.8         4.1       4.160  119098
# 7108      I       3.1          3.5         4.3       3.640   79812
#
#       SALES_PRICE
# 0         7600000
# 1        21717770
# 2        13159200
# 3         9630290
# 4         7406250
# 5        12394750
# 6         8488790
# 7        16800250
# 8         8308970
# 9         8083650
# 10       14938000
# 11        9449730
# 12        8774370
# 13        9386490
# 14       15499680
# 16        8656000
# 17       10912550
# 18        8287550
# 19       21203240
# 20       10905530
# 21        9185970
# 22       10925400
# 23        9627380
# 24       13922760
# 25       12601080
# 26       13383350
# 27        7939625
# 28        8848285
# 29       11338200
# 30       12872430
# ...           ...
# 7079      8017445
# 7080      7611350
# 7081     14280890
# 7082      9782785
# 7083     11129100
# 7084      7543400
# 7085     11956000
# 7086      4587750
# 7087      9120250
# 7088      7164000
# 7089     14025340
# 7090     11095520
# 7091     11437920
# 7092      8610340
# 7093      9420260
# 7094     14155200
# 7095     13308750
# 7096      9593250
# 7097     14111320
# 7098     13944780
# 7099      7371800
# 7100     19501600
# 7101      6211750
# 7102      5643500
# 7103      9387250
# 7104      5353000
# 7105     10818480
# 7106      8351410
# 7107      8507000
# 7108      9976480
#
# [7056 rows x 19 columns]

# %%
#Drop columns having missing values
data.dropna(axis=1,how="any")
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_ROOM    SALE_COND  \
# 0     P03210  Karapakkam      1004            131       3     AbNormal
# 1     P09411  Anna Nagar      1986             26       5     AbNormal
# 2     P01812       Adyar       909             70       3     AbNormal
# 3     P05346   Velachery      1855             14       5       Family
# 4     P06210  Karapakkam      1226             84       3     AbNormal
# 5     P00219    Chrompet      1220             36       4      Partial
# 6     P09105    Chrompet      1167            137       3      Partial
# 7     P09679   Velachery      1847            176       5       Family
# 8     P03377    Chrompet       771            175       2      AdjLand
# 9     P09623   Velachery      1635             74       4     AbNormal
# 10    P09540    Chrompet      1203             78       4      AdjLand
# 11    P07121    Chrompet      1054            143       3      Partial
# 12    P05512    Chrompet      1196            137       3       Family
# 13    P09370       Adyar      1056             83       3      Partial
# 14    P04085   Velachery      1865            157       5       Family
# 15    P06328   Velachery      1868            148       5       Family
# 16    P06039  Karapakkam      1639            175       4  Normal Sale
# 17    P02016    Chrompet       796            134       2      AdjLand
# 18    P08160       Adyar      1136             69       3  Normal Sale
# 19    P01372  Anna Nagar      1902            168       5       Family
# 20    P00936    Chrompet      1069             53       3     AbNormal
# 21    P07346    Chrompet       931             96       3     AbNormal
# 22    P06851    KK Nagar      2010            114       5      Partial
# 23    P04665    Chrompet      1074            100       3     AbNormal
# 24    P00902      TNagar      1972            111       5      AdjLand
# 25    P00293     T Nagar      1685            105       4       Family
# 26    P02235       Adyar      1130             29       3       Family
# 27    P04080  Karapakkam      1301             59       3  Normal Sale
# 28    P02677       Adyar       730            185       2      AdjLand
# 29    P00755     T Nagar      1806            138       5       Family
# ...      ...         ...       ...            ...     ...          ...
# 7079  P01918       Adyar       934             91       3     AbNormal
# 7080  P08039       Adyar       903            108       3     AbNormal
# 7081  P00603     T Nagar      1946            148       5      AdjLand
# 7082  P08060       Adyar       791             71       2      Partial
# 7083  P09758   Velachery      1992            147       5      Partial
# 7084  P07245    Chrompet       858             32       3      Partial
# 7085  P08537    Chrompet       990            181       3     AbNormal
# 7086  P03059  Karapakkam       705            100       2       Family
# 7087  P05763  Karapakkam      1008            194       3      Partial
# 7088  P05164  Karapakkam      1696             48       4  Normal Sale
# 7089  P06915   Velachery      1907             86       5  Normal Sale
# 7090  P02629    KK Nagar      1960             98       5  Normal Sale
# 7091  P03495    KK Nagar      2051             30       5      Partial
# 7092  P00465    Chrompet      1202            134       4       Family
# 7093  P07282   Velachery      1941             90       5     AbNormal
# 7094  P07645    KK Nagar      2456            171       6      AdjLand
# 7095  P08967  Anna Nagar      1955             33       5       Family
# 7096  P03146    Chrompet      1275              3       4     AbNormal
# 7097  P05670  Anna Nagar      1860            174       5     AbNormal
# 7098  P00629  Anna Nagar      1611            144       4      Partial
# 7099  P03828       Adyar       895            197       3      AdjLand
# 7100  P05438     T Nagar      1733            191       4     AbNormal
# 7101  P05042  Karapakkam       666             51       2      AdjLand
# 7102  P05560  Karapakkam       701            100       2     AbNormal
# 7103  P05133  Karapakkam      1462             68       4       Family
# 7104  P03834  Karapakkam       598             51       2      AdjLand
# 7105  P10000   Velachery      1897             52       5       Family
# 7106  P09594   Velachery      1614            152       4  Normal Sale
# 7107  P06508  Karapakkam       787             40       2      Partial
# 7108  P09794   Velachery      1896            156       5      Partial
#
#      PARK_FACIL   BUILDTYPE UTILITY_AVAIL     STREET MZZONE  QS_ROOMS  \
# 0           Yes  Commercial        AllPub      Paved      A       4.0
# 1            No  Commercial        AllPub     Gravel     RH       4.9
# 2           Yes  Commercial           ELO     Gravel     RL       4.1
# 3            No      Others       NoSewr       Paved      I       4.7
# 4           Yes      Others        AllPub     Gravel      C       3.0
# 5            No  Commercial        NoSeWa  No Access     RH       4.5
# 6            No       Other        AllPub  No Access     RL       3.6
# 7            No  Commercial        AllPub     Gravel     RM       2.4
# 8            No      Others       NoSewr       Paved     RM       2.9
# 9            No      Others           ELO  No Access      I       3.1
# 10          Yes  Commercial        AllPub  No Access     RM       4.0
# 11           No      Others       NoSewr      Gravel     RM       2.2
# 12           No      Others       NoSewr   No Access     RL       2.1
# 13          Yes      Others       NoSewr       Paved     RH       2.2
# 14           No  Commercial       NoSewr       Paved     RM       4.8
# 15           No  Commercial       NoSewr      Gravel     RH       3.8
# 16          Yes       House           ELO     Gravel      I       2.3
# 17          Yes  Commercial        AllPub  No Access     RL       3.5
# 18          Yes      Others        AllPub      Paved      A       4.6
# 19          Yes  Commercial           ELO      Paved     RL       4.5
# 20          Yes      Others       NoSewr       Paved     RM       2.8
# 21          Yes      Others           ELO      Paved     RL       4.2
# 22           No      Others       NoSewr      Gravel     RH       3.4
# 23           No      Others       NoSewr      Gravel     RL       3.0
# 24           No      Others       NoSewr   No Access     RH       4.1
# 25           No       House       NoSewr      Gravel     RM       2.8
# 26          Yes  Commercial           ELO      Paved     RH       2.3
# 27          Yes      Others       NoSewr      Gravel      C       2.8
# 28          Yes       House           ELO     Gravel     RL       2.7
# 29           No       House        NoSeWa      Paved     RH       4.1
# ...         ...         ...           ...        ...    ...       ...
# 7079         No      Others        NoSeWa      Paved     RH       2.6
# 7080        Yes       House       NoSewr       Paved      C       4.8
# 7081         No      Others        NoSeWa     Gravel     RH       2.7
# 7082        Yes  Commercial        NoSeWa     Gravel      C       4.9
# 7083         No       House        NoSeWa     Gravel     RM       2.4
# 7084        Yes       House        NoSeWa  No Access     RL       2.9
# 7085         No  Commercial           ELO      Paved     RL       3.0
# 7086        Yes       House           ELO     Gravel      A       4.7
# 7087        Yes  Commercial        NoSeWa  No Access     RL       2.5
# 7088         No       House       NoSewr   No Access     RH       4.9
# 7089         No  Commercial           ELO      Paved      C       2.4
# 7090         No      Others       NoSewr       Paved     RL       5.0
# 7091         No       House       NoSewr      Gravel     RM       3.0
# 7092         No      Others       NoSewr       Paved     RH       3.1
# 7093        Yes       House           ELO  No Access     RH       3.4
# 7094        Yes       House       NoSewr      Gravel     RM       5.0
# 7095         No       House       NoSewr       Paved     RM       3.7
# 7096         No       House           ELO     Gravel     RL       3.9
# 7097         No      Others        AllPub     Gravel     RH       4.6
# 7098        Yes      Others        NoSeWa      Paved     RM       3.2
# 7099        Yes       House       NoSewr   No Access      I       3.6
# 7100        Yes  Commercial        NoSeWa  No Access     RL       3.4
# 7101        Yes      Others           ELO     Gravel      I       3.2
# 7102         No       House        NoSeWa     Gravel     RH       4.2
# 7103         No      Others        NoSeWa     Gravel     RM       2.7
# 7104         No      Others           ELO  No Access     RM       3.0
# 7105        Yes      Others        NoSeWa  No Access     RH       3.6
# 7106         No       House        NoSeWa     Gravel      I       4.3
# 7107        Yes  Commercial           ELO      Paved     RL       4.6
# 7108        Yes      Others           ELO      Paved      I       3.1
#
#       QS_BATHROOM  QS_BEDROOM  COMMIS  SALES_PRICE
# 0             3.9         4.9  144400      7600000
# 1             4.2         2.5  304049     21717770
# 2             3.8         2.2   92114     13159200
# 3             3.9         3.6   77042      9630290
# 4             2.5         4.1   74063      7406250
# 5             2.6         3.1  198316     12394750
# 6             2.1         2.5   33955      8488790
# 7             4.5         2.1  235204     16800250
# 8             3.7         4.0   33236      8308970
# 9             3.1         3.3  121255      8083650
# 10            3.2         4.5  119504     14938000
# 11            3.1         3.3  141746      9449730
# 12            2.5         2.1   35097      8774370
# 13            3.4         3.7   37546      9386490
# 14            2.2         4.9  294494     15499680
# 15            3.8         3.1  188569     15714080
# 16            3.2         4.8   77904      8656000
# 17            4.6         4.7  130951     10912550
# 18            2.6         2.9   49725      8287550
# 19            4.9         4.9  212032     21203240
# 20            2.7         4.9   43622     10905530
# 21            3.1         3.1   27558      9185970
# 22            4.5         3.4  262210     10925400
# 23            3.4         4.9   86646      9627380
# 24            4.4         2.8  167073     13922760
# 25            4.4         4.0  176415     12601080
# 26            2.5         2.2   53533     13383350
# 27            2.7         3.8   71457      7939625
# 28            4.6         4.9   53090      8848285
# 29            5.0         3.0  113382     11338200
# ...           ...         ...     ...          ...
# 7079          4.8         2.0  104227      8017445
# 7080          4.4         4.0   68502      7611350
# 7081          3.8         2.9  171371     14280890
# 7082          3.8         4.2  146742      9782785
# 7083          2.8         2.4  111291     11129100
# 7084          3.0         3.9   30174      7543400
# 7085          4.2         4.8  203252     11956000
# 7086          3.1         4.8   59641      4587750
# 7087          4.5         3.4  200646      9120250
# 7088          4.9         5.0   57312      7164000
# 7089          4.0         4.3  210380     14025340
# 7090          3.7         3.3  122051     11095520
# 7091          2.1         4.4  160131     11437920
# 7092          3.4         3.5   25831      8610340
# 7093          4.6         3.7  141304      9420260
# 7094          5.0         3.0  353880     14155200
# 7095          3.4         2.8  146396     13308750
# 7096          3.8         4.1   86339      9593250
# 7097          3.4         3.2   70557     14111320
# 7098          3.7         2.9  209172     13944780
# 7099          4.7         4.2    7372      7371800
# 7100          3.7         2.1  312026     19501600
# 7101          4.4         2.5   74541      6211750
# 7102          3.0         2.0  141088      5643500
# 7103          3.3         3.6  178358      9387250
# 7104          2.2         2.4  107060      5353000
# 7105          4.5         3.3  205551     10818480
# 7106          4.2         2.9  167028      8351410
# 7107          3.8         4.1  119098      8507000
# 7108          3.5         4.3   79812      9976480
#
# [7109 rows x 16 columns]

# %%
#but this results in data loss

# %%
#Imputing missing values with mean , median or mode

# %%
data["N_BEDROOM"].isnull().sum()
# Out:
# 1

# %%
data["N_BEDROOM"].loc[data["N_BEDROOM"].isnull()==True]
# Out:
# 4060   NaN
# Name: N_BEDROOM, dtype: float64

# %%
data["N_BEDROOM"].fillna(value=data["N_BEDROOM"].mode()[0],inplace=True)

# %%
data["N_BEDROOM"].isnull().sum()
# Out:
# 0

# %%
data["N_BATHROOM"].loc[data["N_BATHROOM"].isnull()==True]
# Out:
# 70     NaN
# 5087   NaN
# 6134   NaN
# 6371   NaN
# 6535   NaN
# Name: N_BATHROOM, dtype: float64

# %%
for i in [70,5087,6134,6371,6535]:
    if data.loc[i,"N_BEDROOM"]==1:
        data["N_BATHROOM"][i]=1
    else:
        data["N_BATHROOM"][i]=2
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
data.loc[data["N_BATHROOM"].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [PRT_ID, AREA, INT_SQFT, DIST_MAINROAD, N_BEDROOM, N_BATHROOM, N_ROOM, SALE_COND, PARK_FACIL, BUILDTYPE, UTILITY_AVAIL, STREET, MZZONE, QS_ROOMS, QS_BATHROOM, QS_BEDROOM, QS_OVERALL, COMMIS, SALES_PRICE]
# Index: []

# %%
data.loc[data["QS_OVERALL"].isnull()==True]
# Out:
#       PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  \
# 15    P06328   Velachery      1868            148        3.0         2.0
# 46    P09483     T Nagar      1882            189        2.0         1.0
# 86    P00545    Chrompet      1085            149        1.0         1.0
# 111   P06768       Adyar      1034             73        1.0         1.0
# 134   P00089     T Nagar      1942             10        2.0         1.0
# 143   P06226  Karapakkam      1430             17        2.0         2.0
# 161   P06964   Velachery      1824            187        3.0         2.0
# 186   P08752       Adyar       738             69        1.0         1.0
# 208   P03292  Karapakkam      1578            153        2.0         2.0
# 248   P04891   Velachery      1776            120        2.0         1.0
# 261   P04590       Adyar      1249             93        2.0         2.0
# 284   P03587    KK Nagar      1632            156        2.0         1.0
# 312   P02964    KK Nagar      2078             13        3.0         2.0
# 329   P01156  Anna Nagar      1585            188        1.0         1.0
# 355   P03358    KK Nagar      1484             54        2.0         1.0
# 402   P04597  Karapakkam      1353             20        2.0         2.0
# 437   P04897    KK Nagar      1450            169        2.0         1.0
# 479   P04286  Karapakkam       984            183        1.0         1.0
# 513   P08647  Anna Nagar      1898            111        2.0         1.0
# 624   P02141  Karapakkam      1352            171        2.0         2.0
# 625   P02698  Anna Nagar      1510            196        1.0         1.0
# 714   P03730  Anna Nagar      1914             66        2.0         1.0
# 769   P01445    Chrompet       944            132        1.0         1.0
# 822   P04352    Chrompet      1258             78        2.0         1.0
# 899   P02853    KK Nagar      1532             60        2.0         1.0
# 955   P02506    Chrompet       976             64        1.0         1.0
# 993   P08954     T Nagar      1519            115        1.0         1.0
# 1044  P03792    KK Nagar      1896            182        3.0         2.0
# 1142  P07495    KK Nagar      2434             28        4.0         2.0
# 1206  P09213  Anna Nagar      1952             53        2.0         1.0
# 1393  P00225  Anna Nagar      2000            102        2.0         1.0
# 1447  P05466    Chrompet      1171             10        1.0         1.0
# 1528  P01678  Anna Nagar      1823             45        2.0         1.0
# 2196  P03342     T Nagar      1639             42        1.0         1.0
# 2227  P08462    Chrompet      1196            116        1.0         1.0
# 2228  P08971    Chrompet      1225             85        2.0         1.0
# 2336  P03084   Velachery      1596             99        2.0         1.0
# 3870  P02851   Velachery      1752             70        2.0         1.0
# 4329  P00239  Anna Nagar      1838            148        2.0         1.0
# 4836  P05101   Velachery      1662             50        2.0         1.0
# 5104  P08589    Chrompet      1022            170        1.0         1.0
# 5458  P02849     T Nagar      1624            117        1.0         1.0
# 5463  P09431       Adyar      1277             30        2.0         2.0
# 6111  P06239  Karapakkam       806             54        1.0         1.0
# 6134  P01332    Chormpet       916            173        1.0         1.0
# 6161  P02241       Adyar      1150            170        1.0         1.0
# 6248  P03983  Karapakkam       931             86        1.0         1.0
# 6855  P09225     T Nagar      1741            106        1.0         1.0
#
#       N_ROOM    SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL     STREET  \
# 15         5       Family         No  Commercial       NoSewr      Gravel
# 46         5     AbNormal        Yes      Others           ELO     Gravel
# 86         3     AbNormal        Yes  Commercial       NoSewr      Gravel
# 111        3      AdjLand        Yes      Others           ELO     Gravel
# 134        5       Family         No       House        NoSeWa     Gravel
# 143        4     AbNormal        Yes      Others       NoSewr   No Access
# 161        5  Normal Sale         No       House       NoSewr       Paved
# 186        2      Partial         No  Commercial       NoSewr   No Access
# 208        4  Normal Sale        Yes      Others        AllPub     Gravel
# 248        4  Normal Sale        Yes       House        NoSeWa      Paved
# 261        4      AdjLand         No  Commercial       NoSewr       Paved
# 284        4      Partial        Yes      Others        AllPub     Gravel
# 312        5     AbNormal         No       House        NoSeWa      Paved
# 329        4       Family         No  Commercial        AllPub  No Access
# 355        4      Partial        Yes       Other       NoSewr      Gravel
# 402        4     AbNormal        Yes      Others           ELO  No Access
# 437        4      AdjLand        Yes      Others        AllPub      Paved
# 479        3       Family        Yes       House       NoSewr   No Access
# 513        5     AbNormal         No      Others        NoSeWa  No Access
# 624        4     AbNormal        Yes  Commercial        NoSeWa     Gravel
# 625        4  Normal Sale         No      Others        NoSeWa      Paved
# 714        5      Partial        Yes       House           ELO     Gravel
# 769        3       Family         No  Commercial       NoSewr       Paved
# 822        4      Partial         No      Others           ELO  No Access
# 899        4      Partial        Yes  Commercial       NoSewr       Paved
# 955        3       Family        Yes  Commercial        NoSeWa      Paved
# 993        4       Family        Yes  Commercial       NoSewr   No Access
# 1044       5      Partial         No      Others        NoSeWa      Paved
# 1142       6      Partial        Yes      Others        NoSeWa     Gravel
# 1206       5      AdjLand        Yes  Commercial        AllPub  No Access
# 1393       5       Family         No  Commercial           ELO      Paved
# 1447       3      AdjLand         No  Commercial        AllPub  No Access
# 1528       5      AdjLand         No      Others        AllPub      Paved
# 2196       4      Partial         No       House           ELO     Gravel
# 2227       3     AbNormal         No      Others        AllPub     Gravel
# 2228       4     AbNormal        Yes      Others        AllPub     Gravel
# 2336       4      Partial        Yes       House        NoSeWa      Paved
# 3870       4       Family        Noo      Others        AllPub  No Access
# 4329       5      Partial        Yes      Others           ELO     Gravel
# 4836       4  Normal Sale        Yes  Commercial           ELO     Gravel
# 5104       3      AdjLand        Yes  Commercial       NoSewr   No Access
# 5458       4  Normal Sale        Yes  Commercial       NoSewr       Paved
# 5463       4      Partial        Yes       House       NoSewr       Paved
# 6111       2      Partial        Yes  Commercial        AllPub  No Access
# 6134       3  Normal Sale        Yes      Others           ELO      Paved
# 6161       3       Family         No  Commercial           ELO  No Access
# 6248       3       Family         No       House           ELO      Paved
# 6855       4       Family        Yes      Others           ELO  No Access
#
#      MZZONE  QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL  COMMIS  \
# 15       RH       3.8          3.8         3.1         NaN  188569
# 46       RM       3.9          4.5         4.7         NaN  272877
# 86       RL       2.8          3.8         4.6         NaN  100545
# 111       C       3.8          3.3         3.5         NaN   46284
# 134      RH       4.6          3.1         2.9         NaN   61654
# 143       A       4.3          3.2         3.8         NaN  106172
# 161       I       3.9          2.3         4.1         NaN   76942
# 186       I       2.4          4.7         5.0         NaN    8313
# 208       I       4.3          4.6         3.4         NaN  238313
# 248      RH       4.9          2.4         3.4         NaN   89903
# 261       A       3.9          2.2         4.8         NaN  176992
# 284      RH       2.7          4.5         2.9         NaN  262661
# 312      RH       2.3          2.8         4.6         NaN  106665
# 329      RL       2.3          4.2         2.1         NaN  104297
# 355      RH       3.4          2.5         4.2         NaN  224733
# 402      RL       3.7          2.3         2.5         NaN   77165
# 437      RH       3.8          4.4         2.4         NaN  251011
# 479       C       2.7          2.7         4.7         NaN   48067
# 513      RM       4.4          2.5         3.2         NaN   94396
# 624       I       3.8          4.0         4.2         NaN  164059
# 625      RH       4.1          4.6         3.0         NaN  175607
# 714      RL       3.6          2.7         3.2         NaN  190346
# 769      RL       4.8          4.6         2.5         NaN  128299
# 822      RH       4.4          4.9         3.3         NaN   32873
# 899      RH       5.0          4.0         3.1         NaN  254703
# 955      RH       4.6          4.7         2.2         NaN   71662
# 993      RM       3.3          4.8         4.7         NaN  127189
# 1044     RL       3.2          3.3         4.3         NaN  230151
# 1142     RM       2.1          4.5         2.1         NaN  272873
# 1206     RH       3.9          2.6         2.4         NaN  126161
# 1393     RL       3.9          5.0         3.1         NaN  334830
# 1447     RM       4.0          4.4         4.8         NaN  238596
# 1528     RH       4.0          3.7         2.0         NaN  134503
# 2196     RM       3.6          3.4         2.8         NaN  192661
# 2227     RM       3.5          4.5         4.3         NaN  189300
# 2228     RH       3.8          4.5         4.7         NaN  177864
# 2336     RM       2.5          3.4         3.4         NaN   96374
# 3870      I       2.6          3.8         3.7         NaN  119498
# 4329     RM       2.1          2.5         4.4         NaN  254549
# 4836      A       2.3          2.8         2.7         NaN  197407
# 5104     RM       2.8          4.5         3.8         NaN   81241
# 5458     RM       5.0          2.5         2.2         NaN  256386
# 5463      C       3.8          4.9         4.0         NaN   25139
# 6111      A       4.9          2.4         2.3         NaN   98433
# 6134     RL       3.4          3.5         3.0         NaN   44237
# 6161      I       2.1          4.8         2.5         NaN  104947
# 6248      I       4.7          5.0         4.9         NaN   82340
# 6855     RM       3.1          4.7         4.6         NaN  167109
#
#       SALES_PRICE
# 15       15714080
# 46       16051580
# 86       14363500
# 111       9256740
# 134      12330740
# 143       6635750
# 161       8549060
# 186       8312670
# 208       9532500
# 248       9989170
# 261      12642285
# 284      10506420
# 312       9696820
# 329      17382790
# 355       9771020
# 402       8573875
# 437      10040420
# 479       5340750
# 513      13485130
# 624      10937250
# 625      10975430
# 714      13596110
# 769      11663500
# 822       8218210
# 899      13405440
# 955      11943700
# 993      18169910
# 1044     10461400
# 1142     14361720
# 1206     21026890
# 1393     20926890
# 1447     14035050
# 1528     13450260
# 2196     12041320
# 2227     11135270
# 2228     11116500
# 2336      9637350
# 3870      8535580
# 4329     14973480
# 4836     13160490
# 5104     13540150
# 5458     19722030
# 5463      8379570
# 6111      5468500
# 6134      8847420
# 6161     11660780
# 6248      5146250
# 6855     13925720

# %%
data[["QS_ROOMS","QS_BATHROOM","QS_BEDROOM","QS_OVERALL"]].head()
# Out:
#    QS_ROOMS  QS_BATHROOM  QS_BEDROOM  QS_OVERALL
# 0       4.0          3.9         4.9       4.330
# 1       4.9          4.2         2.5       3.765
# 2       4.1          3.8         2.2       3.090
# 3       4.7          3.9         3.6       4.010
# 4       3.0          2.5         4.1       3.290

# %%
avg=(data["QS_BATHROOM"]+data["QS_BEDROOM"]+data["QS_ROOMS"])/3

# %%
data.insert(column="Avg",value=avg,loc=17)

# %%
data.head()
# Out:
#    PRT_ID        AREA  INT_SQFT  DIST_MAINROAD  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0  P03210  Karapakkam      1004            131        1.0         1.0       3
# 1  P09411  Anna Nagar      1986             26        2.0         1.0       5
# 2  P01812       Adyar       909             70        1.0         1.0       3
# 3  P05346   Velachery      1855             14        3.0         2.0       5
# 4  P06210  Karapakkam      1226             84        1.0         1.0       3
#
#   SALE_COND PARK_FACIL   BUILDTYPE UTILITY_AVAIL  STREET MZZONE  QS_ROOMS  \
# 0  AbNormal        Yes  Commercial        AllPub   Paved      A       4.0
# 1  AbNormal         No  Commercial        AllPub  Gravel     RH       4.9
# 2  AbNormal        Yes  Commercial           ELO  Gravel     RL       4.1
# 3    Family         No      Others       NoSewr    Paved      I       4.7
# 4  AbNormal        Yes      Others        AllPub  Gravel      C       3.0
#
#    QS_BATHROOM  QS_BEDROOM  QS_OVERALL       Avg  COMMIS  SALES_PRICE
# 0          3.9         4.9       4.330  4.266667  144400      7600000
# 1          4.2         2.5       3.765  3.866667  304049     21717770
# 2          3.8         2.2       3.090  3.366667   92114     13159200
# 3          3.9         3.6       4.010  4.066667   77042      9630290
# 4          2.5         4.1       3.290  3.200000   74063      7406250

# %%
del data["Avg"]

# %%
import numpy as np

# %%
for i in range(0,len(data)):
    if pd.isnull(data["QS_OVERALL"][i])==True:
            data["QS_OVERALL"][i]=(data["QS_BATHROOM"][i]+data["QS_BEDROOM"][i]+data["QS_ROOMS"][i])/3
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.loc[data["QS_OVERALL"].isnull()==True]
# Out:
# Empty DataFrame
# Columns: [PRT_ID, AREA, INT_SQFT, DIST_MAINROAD, N_BEDROOM, N_BATHROOM, N_ROOM, SALE_COND, PARK_FACIL, BUILDTYPE, UTILITY_AVAIL, STREET, MZZONE, QS_ROOMS, QS_BATHROOM, QS_BEDROOM, QS_OVERALL, COMMIS, SALES_PRICE]
# Index: []

# %%
data.dtypes
# Out:
# PRT_ID            object
# AREA              object
# INT_SQFT           int64
# DIST_MAINROAD      int64
# N_BEDROOM        float64
# N_BATHROOM       float64
# N_ROOM             int64
# SALE_COND         object
# PARK_FACIL        object
# BUILDTYPE         object
# UTILITY_AVAIL     object
# STREET            object
# MZZONE            object
# QS_ROOMS         float64
# QS_BATHROOM      float64
# QS_BEDROOM       float64
# QS_OVERALL       float64
# COMMIS             int64
# SALES_PRICE        int64
# dtype: object

# %%
data=data.astype({"N_BEDROOM":"int64","N_BATHROOM":"int64"})

# %%
data.dtypes
# Out:
# PRT_ID            object
# AREA              object
# INT_SQFT           int64
# DIST_MAINROAD      int64
# N_BEDROOM          int64
# N_BATHROOM         int64
# N_ROOM             int64
# SALE_COND         object
# PARK_FACIL        object
# BUILDTYPE         object
# UTILITY_AVAIL     object
# STREET            object
# MZZONE            object
# QS_ROOMS         float64
# QS_BATHROOM      float64
# QS_BEDROOM       float64
# QS_OVERALL       float64
# COMMIS             int64
# SALES_PRICE        int64
# dtype: object

# %% [markdown]
# ### Handling speeling errors

# %%
l=["AREA","SALE_COND","PARK_FACIL","BUILDTYPE","UTILITY_AVAIL","STREET","MZZONE"]

# %%
for i in l:
    print("***********Value count for "+i+"*************")
    print(data[i].value_counts())
    print()
# Out:
# ***********Value count for AREA*************
# Chrompet      1681
# Karapakkam    1363
# KK Nagar       996
# Velachery      979
# Anna Nagar     783
# Adyar          773
# T Nagar        496
# Chrompt          9
# Chormpet         6
# Chrmpet          6
# TNagar           5
# Karapakam        3
# Ana Nagar        3
# Ann Nagar        2
# Velchery         2
# Adyr             1
# KKNagar          1
# Name: AREA, dtype: int64
#
# ***********Value count for SALE_COND*************
# AdjLand        1433
# Partial        1429
# Normal Sale    1423
# AbNormal       1406
# Family         1403
# Adj Land          6
# Ab Normal         5
# Partiall          3
# PartiaLl          1
# Name: SALE_COND, dtype: int64
#
# ***********Value count for PARK_FACIL*************
# Yes    3587
# No     3520
# Noo       2
# Name: PARK_FACIL, dtype: int64
#
# ***********Value count for BUILDTYPE*************
# House         2444
# Commercial    2325
# Others        2310
# Other           26
# Comercial        4
# Name: BUILDTYPE, dtype: int64
#
# ***********Value count for UTILITY_AVAIL*************
# AllPub     1886
# NoSeWa     1871
# NoSewr     1829
# ELO        1522
# All Pub       1
# Name: UTILITY_AVAIL, dtype: int64
#
# ***********Value count for STREET*************
# Paved        2560
# Gravel       2520
# No Access    2010
# Pavd           12
# NoAccess        7
# Name: STREET, dtype: int64
#
# ***********Value count for MZZONE*************
# RL    1858
# RH    1822
# RM    1817
# C      550
# A      537
# I      525
# Name: MZZONE, dtype: int64

# %%
data["STREET"].replace({"NoAccess":"No Access"},inplace=True)
data["STREET"].value_counts()
# Out:
# Paved        2560
# Gravel       2520
# No Access    2017
# Pavd           12
# Name: STREET, dtype: int64

# %%
data["UTILITY_AVAIL"].replace({"All Pub":"AllPub"},inplace=True)
data["UTILITY_AVAIL"].value_counts()
# Out:
# AllPub     1887
# NoSeWa     1871
# NoSewr     1829
# ELO        1522
# Name: UTILITY_AVAIL, dtype: int64

# %%
data["BUILDTYPE"].replace({"Comercial":"Commercial"},inplace=True)
data["BUILDTYPE"].value_counts()
# Out:
# House         2444
# Commercial    2329
# Others        2310
# Other           26
# Name: BUILDTYPE, dtype: int64

# %%
data["PARK_FACIL"].replace({"Noo":"No"},inplace=True)
data["PARK_FACIL"].value_counts()
# Out:
# Yes    3587
# No     3522
# Name: PARK_FACIL, dtype: int64

# %%
data["SALE_COND"].replace({"Adj Land":"AdjLand","Ab Normal":"AbNormal","Partiall":"Partial","PartiaLl":"Partial"},inplace=True)
data["SALE_COND"].value_counts()
# Out:
# AdjLand        1439
# Partial        1433
# Normal Sale    1423
# AbNormal       1411
# Family         1403
# Name: SALE_COND, dtype: int64

# %%
data["AREA"].replace({"Chrompt":"Chrompet","Chormpet":"Chrompet","Chrmpet":"Chrompet","TNagar":"T Nagar","Ana Nagar":"Anna Nagar","Karapakam":"Karapakkam","Ann Nagar":"Anna Nagar","Velchery":"Velachery","Adyr":"Adyar","KKNagar":"KK Nagar"},inplace=True)
data["AREA"].value_counts()
# Out:
# Chrompet      1702
# Karapakkam    1366
# KK Nagar       997
# Velachery      981
# Anna Nagar     788
# Adyar          774
# T Nagar        501
# Name: AREA, dtype: int64

# %%
data.isnull().sum()
# Out:
# PRT_ID           0
# AREA             0
# INT_SQFT         0
# DIST_MAINROAD    0
# N_BEDROOM        0
# N_BATHROOM       0
# N_ROOM           0
# SALE_COND        0
# PARK_FACIL       0
# BUILDTYPE        0
# UTILITY_AVAIL    0
# STREET           0
# MZZONE           0
# QS_ROOMS         0
# QS_BATHROOM      0
# QS_BEDROOM       0
# QS_OVERALL       0
# COMMIS           0
# SALES_PRICE      0
# dtype: int64

# %%
data.dtypes
# Out:
# PRT_ID            object
# AREA              object
# INT_SQFT           int64
# DIST_MAINROAD      int64
# N_BEDROOM          int64
# N_BATHROOM         int64
# N_ROOM             int64
# SALE_COND         object
# PARK_FACIL        object
# BUILDTYPE         object
# UTILITY_AVAIL     object
# STREET            object
# MZZONE            object
# QS_ROOMS         float64
# QS_BATHROOM      float64
# QS_BEDROOM       float64
# QS_OVERALL       float64
# COMMIS             int64
# SALES_PRICE        int64
# dtype: object

# %%
plt.scatter(data["SALE_COND"],data["SALES_PRICE"])

# %%
data["BUILDTYPE"].value_counts()
# Out:
# House         2444
# Commercial    2329
# Others        2310
# Other           26
# Name: BUILDTYPE, dtype: int64

# %%
data["BUILDTYPE"].replace({"Other":"Others"},inplace=True)

# %%
data["BUILDTYPE"].replace({"Others":0,"House":1,"Commercial":2},inplace=True)

# %%
data=data.astype({"BUILDTYPE":"int64"})

# %%
x=data["INT_SQFT"].values.reshape(-1,1)

# %%
y=data["SALES_PRICE"]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.3,random_state=1)

# %%
from sklearn import linear_model

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.coef_
# Out:
# array([5041.15219561])

# %%
reg.score(xtest,ytest)
# Out:
# 0.3752604536543601

# %%
plt.scatter(reg.predict(xtrain),reg.predict(xtrain)-ytrain,color='red',label="Train Data")
plt.scatter(reg.predict(xtest),reg.predict(xtest)-ytest,color='blue',label="Test Data")
plt.legend()

# %%
reg.predict([[2000]])
# Out:
# array([13987494.76417609])

# %%
ytest
# Out:
# 5492    18543840
# 3039     7049500
# 2252     7660600
# 2488    14090500
# 4146     6576375
# 2161    10214695
# 751     13919200
# 1282    11003670
# 5118     8445960
# 1745     6765500
# 3832    14154820
# 354     22024740
# 1736    14211850
# 325     10173980
# 5502    20003050
# 5385     7649800
# 1289     8897050
# 867      8895625
# 5108     6958750
# 3794    10699280
# 2354    14105580
# 5064     9462850
# 941     10763000
# 2040    15329240
# 1791    10858850
# 1373     9840760
# 3501     7675500
# 3705    21208080
# 4402    11177540
# 6991     8729375
#           ...
# 1039    12971150
# 2921     6606250
# 2538    12848450
# 2435    10954860
# 2181     8863750
# 1437     8313550
# 4572     9684200
# 348     15883280
# 1566     8793625
# 5991    17542930
# 2157    13026640
# 1833    13668850
# 3521    14166140
# 1413    10383300
# 2969    11551700
# 4652    18770340
# 4697    10666560
# 701      8519200
# 5167     7497100
# 4200    11559880
# 3642     7187570
# 1398    11351890
# 4504    13003330
# 643      9985710
# 2836     6085250
# 3607     6304750
# 6962     8347500
# 1839     8188000
# 1019    11291220
# 3300     7852185
# Name: SALES_PRICE, Length: 2133, dtype: int64

# %%
from sklearn.metrics import mean_absolute_error as mae

# %%
error=mae(reg.predict(xtest),ytest)

# %%
print(error)
# Out:
# 2322829.0302818306

# %%
plt.plot(xtest,reg.predict(xtest),c="Black")

# %%
x=data[["INT_SQFT","BUILDTYPE"]]
y=data["SALES_PRICE"]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.3,random_state=1)

# %%
reg.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
reg.coef_
# Out:
# array([   5012.28632159, 2007665.29658874])

# %%
reg.score(xtest,ytest)
# Out:
# 0.563374084419912

# %%
plt.style.use("fivethirtyeight")
plt.scatter(reg.predict(xtrain),reg.predict(xtrain)-ytrain,color='red',label="Train Data")
plt.scatter(reg.predict(xtest),reg.predict(xtest)-ytest,color='blue',label="Test Data")
plt.legend()

# %%
reg.predict([[2000,2]])
# Out:
# array([15988244.15428722])

# %%
error=mae(reg.predict(xtest),ytest)
print(error)
# Out:
# 1975168.4042250232
